# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],bins=20)

# %%
sns.distplot(tips['total_bill'],kde=False,bins=20)

# %%
sns.distplot(tips['total_bill'],kde=False,bins=100)

# %%
sns.distplot(tips['total_bill'],hist=False)

# %%
sns.distplot(tips['total_bill'],hist=False , rug=True)

# %%
sns.distplot(tips['total_bill'],hist=False , rug=True , vertical=True)

# %%
#kde_kws={"color": "k", "lw": 3, "label": "KDE"},
#hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "g"})

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)
# Out:
# /home/aboda/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Add regression and kernel density fits:

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# /home/aboda/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex')
# Out:
# /home/aboda/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
iris = sns.load_dataset("iris")
sns.jointplot("sepal_width",'petal_length',data=iris,kind='kde',space=0,color="g")

# %%
g = (sns.jointplot("sepal_length", "sepal_width",data=iris, color="k")
         .plot_joint(sns.kdeplot, zorder=0, n_levels=6))
# Out:
# /home/aboda/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tips)

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue="species")

# %%
sns.pairplot(iris, vars=["sepal_width", "sepal_length"])

# %%
tips = sns.load_dataset('tips')
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])
